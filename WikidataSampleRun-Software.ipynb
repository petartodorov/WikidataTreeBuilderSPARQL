# %%
from WikidataTreeBuilderSPARQL import WikidataTreeQuery
import pandas as pd
import simplejson as json
from datetime import datetime
import re

# %%
print("Program starts at "+str(datetime.now()))
# Out:
# Program starts at 2017-07-27 20:24:41.651602

# %% [markdown]
# We start by looking up all descendants of a given node, and a list of "lookup claims" which are the properties that are relevant, as specified by us:

# %%
tree = WikidataTreeQuery(lookupClaims=["P571", "P275", "P101", "P135", "P348", "P306", "P1482", "P277", "P577", "P366", "P178", "P31", "P279", "P2572", "P3966", "P144","P170","P1324"])

# %% [markdown]
# In this particular example, we have set up the "lookup claims," which are the properties of interest to us for each entry. A full list of parameters for the initialisation function could be found in the docstring of the \_\_init\_\_.

# %% [markdown]
# After initializing the class, we are going to extract all descendants of the node of interest. In this example, it's "software" (Wikidata entry Q7397)

# %%
print("Tree building starts at "+str(datetime.now()))
flare = tree.fromRoot("Q7397", forbidden=["Q7889", "Q28923"])
print("Tree building ends at "+str(datetime.now()))
# Out:
# Tree building starts at 2017-07-27 20:24:48.086157
# Tree building ends at 2017-07-27 20:27:37.281942

# %% [markdown]
# After the tree is built "from root" Q7397, we can save it for vizualisation with d3js :

# %%
with open("flareSoftware.json","wb+") as f:
    json.dump(flare,f,indent=4)

# %% [markdown]
# The result is here : http://webservices.uchange.co/api-viz/flared3-wikidata-software.html
#
# Even if the hierarchical structure is visible, the result is not very user-friendly. We can convert it to human-readable information with the addLabels method :

# %%
flare = tree.addLabels(flare)

# %%
with open("flareSoftwareNamed.json","wb+") as f:
    json.dump(flare,f,indent=4)

# %% [markdown]
# And ta-daa : http://webservices.uchange.co/api-viz/flared3-wikidata-software-named.html

# %% [markdown]
# The tree is useful for visualisation, but for augmentaiton of text data, it is more useful to have the data in a table. The getPrettyDF function returns a dataframe

# %%
df = tree.getPrettyDF()

# %%
df
# Out:
#                                               altLabel_en  \
# 0                                                 gnucash
# 9
# 15                                                    MPI
# 25                                       Frostbite Engine
# 29
# 30
# 31
# 34
# 35
# 36
# 37
# 38                                Microsoft Virtual Earth
# 41
# 43                                          MSN Messenger
# 51      (app server, AP server, Web app server, Web ap...
# 59                                 (message board, forum)
# 62                                  (Epiphany, GNOME Web)
# 76
# 77
# 89
# 92
# 93
# 99
# 100
# 106
# 110
# 133
# 136                                                   OCR
# 147
# 155                                                  Gaim
# ...                                                   ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903
# 113904
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914           unofficial kik usernames sharing website
# 113915
# 113935                    (gu.wikibooks.org, guwikibooks)
# 113937                    (mnwikibooks, mn.wikibooks.org)
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                               altLabel_fr  \
# 0                                                 gnucash
# 9
# 15
# 25
# 29
# 30
# 31
# 34
# 35
# 36                                            intergiciel
# 37
# 38               (Microsoft virtual earth, Virtual Earth)
# 41
# 43                                          MSN Messenger
# 51      (Serveurs d'applications, Serveurs d'applicati...
# 59      (Forum d’échange d’information, Forum Web, Sit...
# 62                                  (Epiphany, GNOME Web)
# 76
# 77
# 89
# 92
# 93
# 99      systems, applications, and products for data p...
# 100
# 106
# 110
# 133
# 136
# 147
# 155
# ...                                                   ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903
# 113904
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915
# 113935
# 113937
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                            description_en  \
# 0                                     accounting software
# 9                                          software suite
# 15          message-passing system for parallel computers
# 25                                            game engine
# 29              derivative of the Ubuntu operating system
# 30
# 31
# 34
# 35
# 36      computer software that provides services to so...
# 37      website that aggregates reviews of music album...
# 38
# 41
# 43                    deprecated instant messaging client
# 51      software framework that provides both faciliti...
# 59                                 online discussion site
# 62                                      GNOME web browser
# 76      instant messaging service and game server browser
# 77
# 89
# 92          Messaging and collaborative software platform
# 93                scripting language created by Apple Inc
# 99      enterprise resource planning software develope...
# 100                                               website
# 106
# 110                                         free software
# 133                                           text editor
# 136
# 147                  computer software to manage projects
# 155     open-source multi-platform instant messaging c...
# ...                                                   ...
# 113896
# 113897
# 113899
# 113900                                   Wikimedia module
# 113901                                   Wikimedia module
# 113902
# 113903
# 113904
# 113909                                   Wikimedia module
# 113910                                   Wikimedia module
# 113911                                   Wikimedia module
# 113912
# 113913
# 113914                  Database containing kik usernames
# 113915                    Jabber messaging client library
# 113935
# 113937
# 113942                               cloud backup service
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                            description_fr     entity  \
# 0                    logiciel de comptabilité personnelle    Q123326
# 9                                   logiciel informatique    Q127141
# 15                                       protocole réseau    Q127879
# 25                                  logiciel informatique    Q124514
# 29                                 système d’exploitation     Q72688
# 30                                  logiciel informatique     Q72914
# 31             plateforme en ligne d'intégration continue     Q73134
# 34                                  logiciel informatique     Q74452
# 35                                     programme d'échecs    Q147428
# 36      logiciel tiers facilitant l'interaction entre ...    Q146768
# 37                                               site web    Q150248
# 38                                  logiciel informatique    Q151524
# 41                                  logiciel informatique    Q148362
# 43      client de messagerie distribué par Microsoft, ...     Q71493
# 51      logiciel d'infrastructure offrant un contexte ...     Q71550
# 59                  espace virtuel de discussion publique    Q168210
# 62                                navigateur web de GNOME    Q167784
# 76                                  logiciel informatique     Q71681
# 77                                  logiciel informatique     Q71694
# 89                                  logiciel informatique     Q71667
# 92                                  logiciel informatique    Q128926
# 93                                  logiciel informatique    Q129137
# 99                                  logiciel informatique    Q167533
# 100                                              site web    Q129070
# 106                                 logiciel informatique    Q166751
# 110                                 logiciel informatique    Q150232
# 133                                 logiciel informatique    Q167140
# 136     procédés informatiques pour la traduction d'im...    Q167555
# 147     logiciel qui supporte la mise en œuvre des tâc...    Q167035
# 155     logiciel libre multiplate-forme client de mess...     Q71380
# ...                                                   ...        ...
# 113896                                                     Q29364592
# 113897                                                     Q29910091
# 113899                                                     Q28130109
# 113900                                                     Q29921745
# 113901                                                     Q29921849
# 113902                                                     Q29916946
# 113903                                                     Q29364615
# 113904                                                     Q29949598
# 113909                                                     Q30003862
# 113910                                                     Q30004735
# 113911                                                     Q30003611
# 113912                                                     Q29996529
# 113913                                                     Q29996526
# 113914                                                     Q29992604
# 113915                                                     Q28000534
# 113935                                                     Q33109650
# 113937                                                     Q33109651
# 113942                                                     Q27998978
# 113959                                                     Q26704509
# 113960                                                     Q26704515
# 113961                                                     Q26704512
# 113962                                                     Q26704518
# 113963                                                     Q26704517
# 113964                                                     Q26704523
# 113965                                                     Q26704521
# 113966                                                     Q26704527
# 113967                                                     Q26704525
# 113968                                                     Q26704531
# 113969                                                     Q26704529
# 113970                                                     Q26704535
#
#                                  label_en  \
# 0                                 GnuCash
# 9                           Microsoft Bob
# 15              Message Passing Interface
# 25                              Frostbite
# 29                                Xubuntu
# 30                                 xmonad
# 31                              Travis CI
# 34                                   MODX
# 35                                  Zappa
# 36                             middleware
# 37                             Metacritic
# 38                     Bing Maps Platform
# 41                                 Zattoo
# 43                 Windows Live Messenger
# 51                     Application server
# 59                         Internet forum
# 62                                    Web
# 76                                  Xfire
# 77                       Yahoo! Messenger
# 89                                 X-Lite
# 92                       Novell GroupWise
# 93                            AppleScript
# 99                                SAP ERP
# 100                   Giveaway of the Day
# 106                             InterBase
# 110                                gThumb
# 133                              Smultron
# 136         optical character recognition
# 147           project management software
# 155                                Pidgin
# ...                                   ...
# 113896                            Nomulus
# 113897                              Anbox
# 113899                         Mapumental
# 113900                    Module:FileData
# 113901           Module:Hockey team color
# 113902                        EternalBlue
# 113903                   Clips (software)
# 113904             Cellosaurus release 22
# 113909                     Module:Respell
# 113910    Module:Television ratings graph
# 113911             Module:Unsubst-infobox
# 113912             Extension:CustomHeader
# 113913  Extension:BlueSpiceInsertTemplate
# 113914                      kik usernames
# 113915                            Swiften
# 113935                  Gujarti Wikibooks
# 113937                Mongolian Wikibooks
# 113942                          rsync.net
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                     label_fr P101_field_of_work  \
# 0                                    GnuCash
# 9                              Microsoft Bob
# 15                 Message Passing Interface
# 25                          Frostbite Engine
# 29                                   Xubuntu
# 30                                    xmonad
# 31                                 Travis CI
# 34                                      MODx
# 35                                     Zappa
# 36                                middleware
# 37                                Metacritic
# 38                  Bing Maps for Enterprise
# 41                                    Zattoo
# 43                    Windows Live Messenger
# 51                    serveur d'applications
# 59                                     forum
# 62                                       Web
# 76                                     Xfire
# 77                          Yahoo! Messenger
# 89                                    X-Lite
# 92                          Novell GroupWise
# 93                               AppleScript
# 99                                   SAP ERP
# 100                      Giveaway of the Day
# 106                                InterBase
# 110                                   gThumb
# 133                                 Smultron
# 136     reconnaissance optique de caractères
# 147           logiciel de gestion de projets
# 155                                   Pidgin
# ...                                      ...                ...
# 113896
# 113897
# 113899                            Mapumental
# 113900
# 113901
# 113902                           EternalBlue
# 113903
# 113904             Version 22 du Cellosaurus
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915                               Swiften
# 113935
# 113937
# 113942                             rsync.net
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                   P1324_source_code_repository           P135_movement  \
# 0           https://github.com/Gnucash/gnucash  free software movement
# 9
# 15
# 25
# 29
# 30
# 31      https://github.com/travis-ci/travis-ci
# 34
# 35
# 36
# 37
# 38
# 41
# 43
# 51
# 59
# 62       https://git.gnome.org/browse/epiphany
# 76
# 77
# 89
# 92
# 93
# 99
# 100
# 106
# 110       https://git.gnome.org/browse/gthumb/
# 133
# 136
# 147
# 155          https://bitbucket.org/pidgin/main
# ...                                        ...                     ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903
# 113904
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915          https://github.com/swift/swift
# 113935
# 113937
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                               ...                          \
# 0                             ...
# 9                             ...
# 15                            ...
# 25                            ...
# 29                            ...
# 30                            ...
# 31                            ...
# 34                            ...
# 35                            ...
# 36                            ...
# 37                            ...
# 38                            ...
# 41                            ...
# 43                            ...
# 51                            ...
# 59                            ...
# 62                            ...
# 76                            ...
# 77                            ...
# 89                            ...
# 92                            ...
# 93                            ...
# 99                            ...
# 100                           ...
# 106                           ...
# 110                           ...
# 133                           ...
# 136                           ...
# 147                           ...
# 155                           ...
# ...                           ...
# 113896                        ...
# 113897                        ...
# 113899                        ...
# 113900                        ...
# 113901                        ...
# 113902                        ...
# 113903                        ...
# 113904                        ...
# 113909                        ...
# 113910                        ...
# 113911                        ...
# 113912                        ...
# 113913                        ...
# 113914                        ...
# 113915                        ...
# 113935                        ...
# 113937                        ...
# 113942                        ...
# 113959                        ...
# 113960                        ...
# 113961                        ...
# 113962                        ...
# 113963                        ...
# 113964                        ...
# 113965                        ...
# 113966                        ...
# 113967                        ...
# 113968                        ...
# 113969                        ...
# 113970                        ...
#
#                                 P277_programming_language  \
# 0                                  (Scheme, C++, C, Java)
# 9
# 15
# 25                                                    C++
# 29
# 30                                                Haskell
# 31                                                   Ruby
# 34                                                    PHP
# 35
# 36
# 37
# 38
# 41
# 43
# 51
# 59
# 62                                               (C++, C)
# 76
# 77
# 89
# 92
# 93
# 99                                         (ABAP, C++, C)
# 100
# 106
# 110                                              (C++, C)
# 133
# 136
# 147
# 155     (Câ™¯, Perl, C, C++, Python, Tool Command Lang...
# ...                                                   ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903
# 113904
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915                                                C++
# 113935
# 113937
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                          P279_subclass_of  \
# 0
# 9
# 15
# 25
# 29
# 30
# 31
# 34
# 35
# 36                                        system software
# 37
# 38
# 41
# 43
# 51                                        server software
# 59      (service on internet, website, virtual community)
# 62
# 76
# 77
# 89
# 92
# 93
# 99
# 100
# 106
# 110
# 133
# 136                                             algorithm
# 147                                              software
# 155
# ...                                                   ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903
# 113904
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915
# 113935
# 113937
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                     P306_operating_system  \
# 0       (Microsoft Windows, GNU, Android, GNU/Linux, F...
# 9                                            Windows 3.1x
# 15
# 25                                      Microsoft Windows
# 29
# 30
# 31
# 34
# 35
# 36
# 37
# 38                                      Microsoft Windows
# 41
# 43      (Windows Mobile, BlackBerry OS, Android, Symbi...
# 51
# 59
# 62      (GNU/Linux, Mac OS, Berkeley Software Distribu...
# 76
# 77
# 89
# 92
# 93
# 99
# 100
# 106
# 110                                                 Linux
# 133
# 136
# 147
# 155     (GNU/Linux, Solaris, Berkeley Software Distrib...
# ...                                                   ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903
# 113904
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915
# 113935
# 113937
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                          P31_instance_of  \
# 0                           personal accounting software
# 9             (software suite, graphical user interface)
# 15                    (library, communications protocol)
# 25                                           game engine
# 29                (Linux distribution, operating system)
# 30                                 Tiling window manager
# 31            (website, continuous integration software)
# 34                             content management system
# 35                                          chess engine
# 36                                      type of software
# 37                          (website, review aggregator)
# 38                                              software
# 41                       (business enterprise, software)
# 43      (proprietary software, instant messaging client)
# 51
# 59                                        internet genre
# 62                                           web browser
# 76                                           application
# 77                                              software
# 89                                              software
# 92                              (email system, software)
# 93            (scripting language, programming language)
# 99                                          ERP software
# 100                                  (website, software)
# 106                                             software
# 110                                         image viewer
# 133                                          text editor
# 136                                             software
# 147                                     type of software
# 155                             instant messaging client
# ...                                                  ...
# 113896                                          software
# 113897                                          software
# 113899                                          software
# 113900                                  Wikimedia module
# 113901                                  Wikimedia module
# 113902                                           exploit
# 113903                                          software
# 113904                                       Cellosaurus
# 113909                                  Wikimedia module
# 113910                                  Wikimedia module
# 113911                                  Wikimedia module
# 113912                               MediaWiki extension
# 113913                               MediaWiki extension
# 113914                                     Kik Messenger
# 113915                   (open-source software, library)
# 113935                        Wikibooks language edition
# 113937                        Wikibooks language edition
# 113942                           Online service provider
# 113959                                Wikimedia KML file
# 113960                                Wikimedia KML file
# 113961                                Wikimedia KML file
# 113962                                Wikimedia KML file
# 113963                                Wikimedia KML file
# 113964                                Wikimedia KML file
# 113965                                Wikimedia KML file
# 113966                                Wikimedia KML file
# 113967                                Wikimedia KML file
# 113968                                Wikimedia KML file
# 113969                                Wikimedia KML file
# 113970                                Wikimedia KML file
#
#        P348_software_version                      P366_use  \
# 0                 2.6.112016
# 9           1.0a c Plus Pack
# 15
# 25
# 29                     17.04
# 30
# 31
# 34                     2.4.4
# 35
# 36
# 37
# 38                                                 science
# 41
# 43             16.4.3505.912
# 51
# 59
# 62         (3.21.90, 3.20.3)
# 76                      2.22
# 77
# 89
# 92
# 93
# 99                            enterprise resource planning
# 100
# 106
# 110                  3.4.4.1
# 133                    8.2.3
# 136                                                science
# 147                                     project management
# 155                   2.12.0
# ...                      ...                           ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903
# 113904
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915
# 113935
# 113937
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#        P3966_programming_paradigm        P571_inception P577_publication_date  \
# 0
# 9
# 15
# 25
# 29                                                       2016-04-21T00:00:00Z
# 30
# 31
# 34
# 35
# 36
# 37                                 2001-01-01T00:00:00Z
# 38                                 2005-01-01T00:00:00Z
# 41                                 2005-05-01T00:00:00Z
# 43
# 51
# 59
# 62                                 2002-12-24T00:00:00Z
# 76
# 77
# 89
# 92
# 93                                 1993-01-01T00:00:00Z
# 99                                                       1993-01-01T00:00:00Z
# 100                                2007-09-27T00:00:00Z
# 106
# 110                                2001-01-01T00:00:00Z
# 133
# 136
# 147
# 155                                1998-12-31T00:00:00Z
# ...                           ...                   ...                   ...
# 113896
# 113897
# 113899
# 113900
# 113901
# 113902
# 113903                             2017-04-06T00:00:00Z
# 113904                                                   2017-05-15T00:00:00Z
# 113909
# 113910
# 113911
# 113912
# 113913
# 113914
# 113915
# 113935
# 113937
# 113942
# 113959
# 113960
# 113961
# 113962
# 113963
# 113964
# 113965
# 113966
# 113967
# 113968
# 113969
# 113970
#
#                                              visitedNodes
# 0       ((software, accounting software, personal acco...
# 9       ((software, software suite), (software, system...
# 15      ((software, system software, utility software,...
# 25      ((software, system software, middleware, game ...
# 29      ((software, system software, operating system,...
# 30      ((software, system software, window manager, T...
# 31         ((software, continuous integration software),)
# 34      ((software, content management system), (softw...
# 35      ((software, program, computer program, chess e...
# 36                         ((software, system software),)
# 37      ((software, system software, middleware, middl...
# 38                                         ((software,),)
# 41                                         ((software,),)
# 43      ((software, system software, middleware, middl...
# 51                         ((software, server software),)
# 59      ((software, system software, middleware, middl...
# 62      ((software, application, web browser), (softwa...
# 76                             ((software, application),)
# 77                                         ((software,),)
# 89                                         ((software,),)
# 92                                         ((software,),)
# 93      ((software, system software, utility software,...
# 99                            ((software, ERP software),)
# 100                                        ((software,),)
# 106                                        ((software,),)
# 110              ((software, application, image viewer),)
# 133       ((software, application, editor, text editor),)
# 136                                        ((software,),)
# 147                                        ((software,),)
# 155     ((software, system software, middleware, middl...
# ...                                                   ...
# 113896                                     ((software,),)
# 113897                                     ((software,),)
# 113899                                     ((software,),)
# 113900  ((software, software component, software exten...
# 113901  ((software, software component, software exten...
# 113902                             ((software, exploit),)
# 113903                                     ((software,),)
# 113904  ((software, system software, middleware, middl...
# 113909  ((software, software component, software exten...
# 113910  ((software, software component, software exten...
# 113911  ((software, software component, software exten...
# 113912  ((software, software component, software exten...
# 113913  ((software, software component, software exten...
# 113914                       ((software, Kik Messenger),)
# 113915  ((software, system software, utility software,...
# 113935  ((software, program, computer program, softwar...
# 113937  ((software, program, computer program, softwar...
# 113942  ((software, system software, middleware, middl...
# 113959  ((software, system software, utility software,...
# 113960  ((software, system software, utility software,...
# 113961  ((software, system software, utility software,...
# 113962  ((software, system software, utility software,...
# 113963  ((software, system software, utility software,...
# 113964  ((software, system software, utility software,...
# 113965  ((software, system software, utility software,...
# 113966  ((software, system software, utility software,...
# 113967  ((software, system software, utility software,...
# 113968  ((software, system software, utility software,...
# 113969  ((software, system software, utility software,...
# 113970  ((software, system software, utility software,...
#
# [44206 rows x 26 columns]

# %%
df.to_excel("tableSoftware.xlsx")

# %%
print("Program end at "+str(datetime.now()))
# Out:
# Program end at 2017-07-27 20:50:04.150030

# %% [markdown]
# And voilà! We have the table of all descendants of the node 'software' with all the properties we think relevant!
