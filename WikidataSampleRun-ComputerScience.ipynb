# %%
import WikidataTreeBuilderSPARQL
reload(WikidataTreeBuilderSPARQL)
import pandas as pd
import simplejson as json
from datetime import datetime
import re

# %%
print("Program starts at "+str(datetime.now()))
# Out:
# Program starts at 2017-07-27 20:13:29.130352

# %% [markdown]
# We start by looking up all descendants of a given node, and a list of "lookup claims" which are the properties that are relevant, as specified by us:

# %%
tree = WikidataTreeBuilderSPARQL.WikidataTreeQuery(lookupClaims=["P571", "P275", "P101", "P135", "P348", "P306", "P1482", "P277", "P577", "P366", "P178", "P31", "P279", "P2572", "P3966", "P144","P170","P1324"])

# %% [markdown]
# In this particular example, we have set up the "lookup claims," which are the properties of interest to us for each entry. A full list of parameters for the initialisation function could be found in the docstring of the \_\_init\_\_.

# %% [markdown]
# After initializing the class, we are going to extract all descendants of the node of interest. In this example, it's "Computer Science" (Wikidata entry Q21198)

# %%
print("Tree building starts at "+str(datetime.now()))
flare = tree.fromRoot("Q21198")
print("Tree building ends at "+str(datetime.now()))
# Out:
# Tree building starts at 2017-07-27 20:13:36.453819
# Tree building ends at 2017-07-27 20:13:37.285849

# %% [markdown]
# After the tree is built "from root" Q21198, we can save it for vizualisation with d3js :

# %%
with open("flareCS.json","wb+") as f:
    json.dump(flare,f,indent=4)

# %% [markdown]
# The result is here : http://webservices.uchange.co/api-viz/flared3-wikidata-cs.html
#
# Even if the hierarchical structure is visible, the result is not very user-friendly. We can convert it to human-readable information with the addLabels method :

# %%
flare = tree.addLabels(flare)

# %%
with open("flareCSNamed.json","wb+") as f:
    json.dump(flare,f,indent=4)

# %% [markdown]
# And ta-daa : http://webservices.uchange.co/api-viz/flared3-wikidata-cs-named.html

# %% [markdown]
# The tree is useful for visualisation, but for augmentaiton of text data, it is more useful to have the data in a table. The getPrettyDF function returns a dataframe

# %%
df = tree.getPrettyDF()

# %%
df
# Out:
#                                             altLabel_en  \
# 0                      (scikit, scikits.learn, sklearn)
# 10
# 26
# 41    (desktop picture, desktop image, desktop wallp...
# 51
# 54    (science of computing, computing science, comp...
# 58                                  (Alentejo, Ireland)
# 61
# 64
# 70                                                   AI
# 82                                           IBM Watson
# 113                                                  ML
# 150                                               Spark
# 270          Waikato Environment for Knowledge Analysis
# 271                       (SVM, support vector machine)
# 273   (ANN, connectionist system, neural network, NN...
# 301
# 316   (document categorization, Document classificat...
# 340                            Computer graphics、略称: CG
# 354                         supervised machine learning
# 675
# 681
# 692
# 705                                    cluster analysis
# 716
# 725                                   transfer learning
# 736
# 755                               Strong AI and Weak AI
# 764                                  computer heuristic
# 766
# ...                                                 ...
# 3203
# 3204                                 text summarization
# 3205                          sequential pattern mining
# 3206
# 3207
# 3208
# 3209
# 3210                                   decision support
# 3211
# 3212
# 3213
# 3214                             structured data mining
# 3215
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228
# 3229
# 3230
# 3231                           Least Mean Square Filter
# 3232
# 3233
# 3234                    (RNN, Recurrent neural network)
# 3235                         quantum information theory
# 3236
# 3237
# 3238
# 3240
#
#                                             altLabel_fr  \
# 0                                          scikit.learn
# 10
# 26    (Algorithme de fourmis, ACO, Algorithmes de co...
# 41    (Fond d'ecran, Wallpaper, Fonds d'écran, Fond ...
# 51
# 54    (science informatique, informatique théorique,...
# 58                                                Bliss
# 61
# 64
# 70
# 82                                           IBM Watson
# 113       (machine learning, apprentissage statistique)
# 150
# 270
# 271   (séparateurs à vaste marge, SVM, support vecto...
# 273   (réseau de neuronnes, reseau de neurones, rese...
# 301
# 316
# 340   (Synthèse d'image, Computer Graphics, Synthèse...
# 354   (Apprentissage supervise, Apprentissage Superv...
# 675                                                 NCP
# 681
# 692
# 705                          Classification Automatique
# 716
# 725
# 736
# 755                                            IA forte
# 764
# 766                        (data science, data-science)
# ...                                                 ...
# 3203
# 3204                                 Résumé automatique
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217  (Théorie de la complexité algorithmique, Theor...
# 3219
# 3222
# 3223             Diagnostic (Intelligence Artificielle)
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234                      Reseau de neurones recurrents
# 3235                             Informatique Quantique
# 3236
# 3237
# 3238
# 3240
#
#                                          description_en  \
# 0     Machine learning library for the Python progra...
# 10
# 26
# 41    digital image used as a decorative background ...
# 51                     specialized field of engineering
# 54    study of the theoretical foundations of inform...
# 58             default computer wallpaper of Windows XP
# 61
# 64                    machine learning software library
# 70    branch of computer science that develops machi...
# 82    artificial intelligence computer system made b...
# 113   construction and study of systems that can lea...
# 150   open-source data analytics cluster computing f...
# 270   suite of machine learning software written in ...
# 271   set of methods for supervised statistical lear...
# 273   computational model used in machine learning, ...
# 301   design, construction, operation, and applicati...
# 316   problem in library science, information scienc...
# 340                          sub-field computer science
# 354                       field within machine learning
# 675
# 681     subfield of computer science and of mathematics
# 692
# 705                              in supervised learning
# 716                                   American composer
# 725                        subfield of machine learning
# 736
# 755
# 764
# 766   interdisciplinary field about processes and sy...
# ...                                                 ...
# 3203                          artificial neural network
# 3204
# 3205
# 3206  research area in semantic similarities between...
# 3207                            planning and organizing
# 3208
# 3209
# 3210
# 3211  an artificial neural network that uses radial ...
# 3212
# 3213  fictional artificial intelligence and main ant...
# 3214
# 3215  filed of research related to recognizing the a...
# 3216  artificial neural network based expert systems...
# 3217
# 3219
# 3222
# 3223
# 3228                              medical expert system
# 3229
# 3230
# 3231                                          algorithm
# 3232
# 3233
# 3234  a class of artificial neural network where con...
# 3235
# 3236
# 3237
# 3238
# 3240
#
#                                          description_fr     entity  \
# 0          librairie Python d'apprentissage statistique   Q1026367
# 10                                  notion informatique    Q844824
# 26    algorithmes inspirés du comportement des fourm...    Q460851
# 41                                                        Q1139104
# 51                       Domaine de la science en génie    Q365674
# 54                      domaine d'activité scientifique     Q21198
# 58    Le fond d'écran installé par défaut sur Window...      Q2368
# 61                     module électronique programmable  Q23773905
# 64                librairie d'apprentissage automatique  Q21447895
# 70    recherche de moyens susceptibles de doter les ...     Q11660
# 82    programme informatique d'intelligence artifici...     Q12253
# 113   un des champs d'étude de l'intelligence artifi...      Q2539
# 150      Plateforme de traitement de données distribué.   Q7573619
# 270                               logiciel informatique    Q115494
# 271    ensemble de techniques d'apprentissage supervisé    Q282453
# 273   modèle de calcul inspiré des neurones biologiques    Q192776
# 301   terme collectif pour la conception, la constru...    Q170978
# 316       traitement automatique des langues naturelles    Q302088
# 340                      champ d'études en informatique    Q150971
# 354               technique d'apprentissage automatique    Q334384
# 675              Magazine de presse écrite informatique   Q7006669
# 681   sous-discipline de l'informatique et des mathé...   Q2878974
# 692   familles algorithme d’optimisation visant à ré...   Q1385229
# 705               catégorisation algorithmique d'objets   Q1744628
# 716                  Programme informatique compositeur   Q5372219
# 725   l'un des champs de recherche de l'apprentissag...   Q6027324
# 736                               magazine informatique   Q5380160
# 755                    type d'intelligence artificielle   Q2264109
# 764   technique de résolution de problème non exacte...   Q1981968
# 766   discipline qui comprend des éléments de statis...   Q2374463
# ...                                                 ...        ...
# 3203                                                      Q7316287
# 3204                                                      Q1394144
# 3205                                                      Q1718507
# 3206                                                      Q5283209
# 3207                                                      Q4117674
# 3208                                                      Q4724363
# 3209                                                      Q4724364
# 3210                                                      Q1641902
# 3211                                                      Q2679684
# 3212                                                      Q5514059
# 3213                                                      Q2079562
# 3214                                                      Q3784250
# 3215                                                      Q4677630
# 3216                                                      Q5161689
# 3217                                                      Q1757543
# 3219                                                      Q1938404
# 3222                                                      Q1407668
# 3223                                                      Q3025858
# 3228                                                      Q5008578
# 3229                                                      Q4724365
# 3230                                                      Q5227318
# 3231                                                      Q1426666
# 3232                                                      Q2737866
# 3233                                                      Q5133829
# 3234                                                      Q1457734
# 3235                                                      Q2122216
# 3236                                                      Q4316454
# 3237                                                      Q5156806
# 3238                                                      Q5441227
# 3240                                                      Q1582085
#
#                                      label_en  \
# 0                                scikit-learn
# 10                           Physical address
# 26         Ant colony optimization algorithms
# 41                         computer wallpaper
# 51                       security engineering
# 54                           computer science
# 58                                      Bliss
# 61
# 64                                 TensorFlow
# 70                    artificial intelligence
# 82                                     Watson
# 113                          machine learning
# 150                              Apache Spark
# 270                                      Weka
# 271                    Support vector machine
# 273                 artificial neural network
# 301                                  robotics
# 316                   document classification
# 340                         computer graphics
# 354                       supervised learning
# 675                      New Computer Express
# 681              theoretical computer science
# 692                             Metaheuristic
# 705                statistical classification
# 716                              Emily Howell
# 725                        Inductive transfer
# 736                                     Enter
# 755                                 Strong AI
# 764                                 Heuristic
# 766                              data science
# ...                                       ...
# 3203             Restricted Boltzmann machine
# 3204                  automatic summarization
# 3205                          sequence mining
# 3206                 distributional semantics
# 3207                          Self-management
# 3208                    Algorithmic inference
# 3209              Algorithmic learning theory
# 3210        Automated Decision support system
# 3211            Radial basis function network
# 3212                                    GOFAI
# 3213                                   SHODAN
# 3214                         structure mining
# 3215                     Activity recognition
# 3216              connectionist expert system
# 3217           Algorithmic information theory
# 3219                       social informatics
# 3222                         Hopfield network
# 3223                                Diagnosis
# 3228                                 CADUCEUS
# 3229                  Algorithmic probability
# 3230               data mining in meteorology
# 3231                Least mean squares filter
# 3232                 scientific visualization
# 3233         Clinical decision support system
# 3234                 recurrent neural network
# 3235              Quantum information science
# 3236                   Kohonen neural network
# 3237  Compositional pattern-producing network
# 3238               Feedforward neural network
# 3240                     knowledge extraction
#
#                                            label_fr  \
# 0                                      scikit-learn
# 10                                 Adresse physique
# 26                Algorithme de colonies de fourmis
# 41                                     fond d'écran
# 51                          technologie de sécurité
# 54                                     informatique
# 58                               Colline verdoyante
# 61                                           kidule
# 64                                       TensorFlow
# 70                        intelligence artificielle
# 82                                           Watson
# 113                       apprentissage automatique
# 150                                    Apache Spark
# 270                                            Weka
# 271                   machine à vecteurs de support
# 273                  réseau de neurones artificiels
# 301                                       robotique
# 316   classification et catégorisation de documents
# 340                                     infographie
# 354                         apprentissage supervisé
# 675                            New Computer Express
# 681                          informatique théorique
# 692                                 métaheuristique
# 705                      classification automatique
# 716                                    Emily Howell
# 725                     Apprentissage par transfert
# 736                                           Enter
# 755                 intelligence artificielle forte
# 764                                     heuristique
# 766                             science des données
# ...                                             ...
# 3203                machine de Boltzmann restreinte
# 3204                    Résumé automatique de texte
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213                                         SHODAN
# 3214
# 3215
# 3216
# 3217         Théorie algorithmique de l'information
# 3219
# 3222                 réseau de neurones de Hopfield
# 3223                                     Diagnostic
# 3228                                       CADUCEUS
# 3229
# 3230
# 3231
# 3232                     Visualisation scientifique
# 3233         systèmes d'aide à la décision clinique
# 3234                  réseau de neurones récurrents
# 3235                         Informatique quantique
# 3236      Réseau de neurones artificiels de Kohonen
# 3237
# 3238
# 3240                    Extraction de connaissances
#
#                                      P101_field_of_work  \
# 0
# 10
# 26
# 41
# 51
# 54
# 58
# 61
# 64
# 70
# 82
# 113
# 150   (big data, database, distributed computing, fu...
# 270                                    machine learning
# 271
# 273
# 301
# 316
# 340
# 354
# 675
# 681
# 692
# 705
# 716
# 725
# 736
# 755
# 764
# 766
# ...                                                 ...
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233                               diagnostic procedure
# 3234
# 3235
# 3236
# 3237
# 3238
# 3240
#
#                       P1324_source_code_repository  \
# 0     https://github.com/scikit-learn/scikit-learn
# 10
# 26
# 41
# 51
# 54
# 58
# 61
# 64        https://github.com/tensorflow/tensorflow
# 70
# 82
# 113
# 150                https://github.com/apache/spark
# 270        https://svn.cms.waikato.ac.nz/svn/weka/
# 271
# 273
# 301
# 316
# 340
# 354
# 675
# 681
# 692
# 705
# 716
# 725
# 736
# 755
# 764
# 766
# ...                                            ...
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3240
#
#                                P1482_Stack_Exchange_tag  \
# 0
# 10
# 26            https://stackoverflow.com/tags/ant-colony
# 41
# 51
# 54      https://stackoverflow.com/tags/computer-science
# 58
# 61
# 64
# 70
# 82
# 113
# 150
# 270
# 271                  https://stackoverflow.com/tags/svm
# 273
# 301
# 316   https://stackoverflow.com/tags/document-classi...
# 340
# 354
# 675
# 681
# 692
# 705       https://stackoverflow.com/tags/classification
# 716
# 725
# 736
# 755
# 764
# 766
# ...                                                 ...
# 3203                 https://stackoverflow.com/tags/rbm
# 3204       https://stackoverflow.com/tags/summarization
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3240
#
#                             ...                         P275_license  \
# 0                           ...                          BSD license
# 10                          ...
# 26                          ...
# 41                          ...
# 51                          ...
# 54                          ...
# 58                          ...
# 61                          ...
# 64                          ...                           Apache-2.0
# 70                          ...
# 82                          ...
# 113                         ...
# 150                         ...                           Apache-2.0
# 270                         ...                              GPL-3.0
# 271                         ...
# 273                         ...
# 301                         ...
# 316                         ...
# 340                         ...
# 354                         ...
# 675                         ...
# 681                         ...
# 692                         ...
# 705                         ...
# 716                         ...
# 725                         ...
# 736                         ...
# 755                         ...
# 764                         ...
# 766                         ...
# ...                         ...                                  ...
# 3203                        ...
# 3204                        ...
# 3205                        ...
# 3206                        ...
# 3207                        ...
# 3208                        ...
# 3209                        ...
# 3210                        ...
# 3211                        ...
# 3212                        ...
# 3213                        ...
# 3214                        ...
# 3215                        ...
# 3216                        ...
# 3217                        ...
# 3219                        ...
# 3222                        ...
# 3223                        ...
# 3228                        ...
# 3229                        ...
# 3230                        ...
# 3231                        ...
# 3232                        ...
# 3233                        ...
# 3234                        ...
# 3235                        ...
# 3236                        ...
# 3237                        ...
# 3238                        ...
# 3240                        ...
#
#      P277_programming_language  \
# 0     (Python, C++, C, Cython)
# 10
# 26
# 41
# 51
# 54
# 58
# 61
# 64               (Python, C++)
# 70
# 82
# 113
# 150   (R, Python, Scala, Java)
# 270                       Java
# 271
# 273
# 301
# 316
# 340
# 354
# 675
# 681
# 692
# 705
# 716
# 725
# 736
# 755
# 764
# 766
# ...                        ...
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3240
#
#                                        P279_subclass_of  \
# 0
# 10
# 26                               optimization algorithm
# 41                  (visual artwork, computer graphics)
# 51                      (engineering, computer science)
# 54            (engineering disciplines, formal science)
# 58
# 61
# 64
# 70    (artificial entity, computer science, algorith...
# 82                                             computer
# 113         (computer science, artificial intelligence)
# 150
# 270
# 271                                 supervised learning
# 273                             artificial intelligence
# 301                            mechatronics engineering
# 316                          statistical classification
# 340                                    computer science
# 354                                    machine learning
# 675
# 681                                    computer science
# 692                                           Heuristic
# 705                                    machine learning
# 716
# 725                                    machine learning
# 736
# 755                             artificial intelligence
# 764                (artificial intelligence, algorithm)
# 766                      (computer science, statistics)
# ...                                                 ...
# 3203
# 3204                                        text mining
# 3205                                   structure mining
# 3206             (semantics, computational linguistics)
# 3207                            artificial intelligence
# 3208
# 3209
# 3210                            decision support system
# 3211                          artificial neural network
# 3212                            artificial intelligence
# 3213
# 3214                                        data mining
# 3215                                   computer science
# 3216                          artificial neural network
# 3217
# 3219                                   computer science
# 3222                          artificial neural network
# 3223                            decision support system
# 3228
# 3229
# 3230                                        data mining
# 3231
# 3232                              computational science
# 3233                            decision support system
# 3234                          artificial neural network
# 3235                                   computer science
# 3236                          artificial neural network
# 3237
# 3238                          artificial neural network
# 3240                                        data mining
#
#                   P306_operating_system  \
# 0
# 10
# 26
# 41
# 51
# 54
# 58
# 61
# 64
# 70
# 82
# 113
# 150   (Microsoft Windows, macOS, Linux)
# 270
# 271
# 273
# 301
# 316
# 340
# 354
# 675
# 681
# 692
# 705
# 716
# 725
# 736
# 755
# 764
# 766
# ...                                 ...
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3240
#
#                                         P31_instance_of  \
# 0           (library, Python library, machine learning)
# 10                                     computer science
# 26                                        Metaheuristic
# 41
# 51           (interdisciplinary science, special field)
# 54                                  academic discipline
# 58                     (photograph, computer wallpaper)
# 61                                             robotics
# 64    (free software, library, software framework, m...
# 70
# 82    (supercomputer, artificial intelligence, one-o...
# 113
# 150   (free software, machine learning Framework, so...
# 270                          machine learning Framework
# 271                                           algorithm
# 273
# 301                     (academic discipline, industry)
# 316
# 340                                       special field
# 354                                           algorithm
# 675                        (computer science, magazine)
# 681
# 692
# 705
# 716      (artificial intelligence, fictional character)
# 725
# 736                        (computer science, magazine)
# 755
# 764
# 766                                 academic discipline
# ...                                                 ...
# 3203                          artificial neural network
# 3204
# 3205
# 3206                                      field of work
# 3207
# 3208                                   machine learning
# 3209                                   machine learning
# 3210
# 3211
# 3212
# 3213     (artificial intelligence, fictional character)
# 3214
# 3215
# 3216
# 3217  (theoretical computer science, information the...
# 3219
# 3222
# 3223
# 3228                          (expert system, software)
# 3229                     Algorithmic information theory
# 3230
# 3231               (online machine learning, algorithm)
# 3232                                           software
# 3233                                   type of software
# 3234
# 3235
# 3236
# 3237                          artificial neural network
# 3238
# 3240
#
#                                   P348_software_version           P366_use  \
# 0                                                0.18.1
# 10
# 26
# 41
# 51
# 54
# 58
# 61
# 64                                                1.2.1   machine learning
# 70
# 82
# 113
# 150   (1.4.0, 1.4.1, 2.0.1, 2.0.0, 1.5.1, 1.5.0, 1.5...
# 270                                                                science
# 271
# 273
# 301
# 316
# 340                                                      computer graphics
# 354
# 675
# 681
# 692
# 705
# 716
# 725
# 736
# 755
# 764
# 766
# ...                                                 ...                ...
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215                                                               science
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228                                                               science
# 3229
# 3230
# 3231
# 3232                                                               science
# 3233                                                               science
# 3234
# 3235
# 3236
# 3237
# 3238
# 3240
#
#             P571_inception P577_publication_date  \
# 0
# 10
# 26
# 41
# 51
# 54
# 58    1996-01-01T00:00:00Z
# 61
# 64
# 70
# 82
# 113
# 150   2014-05-30T00:00:00Z
# 270
# 271   1963-01-01T00:00:00Z
# 273
# 301
# 316
# 340
# 354
# 675   1988-01-01T00:00:00Z
# 681
# 692
# 705
# 716
# 725
# 736   1983-10-01T00:00:00Z
# 755
# 764
# 766
# ...                    ...                   ...
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3219
# 3222
# 3223
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3240
#
#                                            visitedNodes
# 0     ((computer science, machine learning), (comput...
# 10                               ((computer science,),)
# 26    ((computer science, artificial intelligence, H...
# 41             ((computer science, computer graphics),)
# 51                               ((computer science,),)
# 54                                                ((),)
# 58    ((computer science, computer graphics, compute...
# 61    ((computer science, mechatronics engineering, ...
# 64    ((computer science, machine learning), (comput...
# 70                               ((computer science,),)
# 82       ((computer science, artificial intelligence),)
# 113   ((computer science,), (computer science, artif...
# 150   ((computer science, machine learning, machine ...
# 270   ((computer science, machine learning, machine ...
# 271   ((computer science, machine learning, supervis...
# 273      ((computer science, artificial intelligence),)
# 301     ((computer science, mechatronics engineering),)
# 316   ((computer science, machine learning, statisti...
# 340                              ((computer science,),)
# 354   ((computer science, machine learning), (comput...
# 675                              ((computer science,),)
# 681                              ((computer science,),)
# 692   ((computer science, artificial intelligence, H...
# 705   ((computer science, machine learning), (comput...
# 716      ((computer science, artificial intelligence),)
# 725   ((computer science, machine learning), (comput...
# 736                              ((computer science,),)
# 755      ((computer science, artificial intelligence),)
# 764      ((computer science, artificial intelligence),)
# 766                              ((computer science,),)
# ...                                                 ...
# 3203  ((computer science, artificial intelligence, a...
# 3204    ((computer science, data mining, text mining),)
# 3205  ((computer science, data mining, structure min...
# 3206   ((computer science, computational linguistics),)
# 3207     ((computer science, artificial intelligence),)
# 3208  ((computer science, machine learning), (comput...
# 3209  ((computer science, machine learning), (comput...
# 3210  ((computer science, artificial intelligence, d...
# 3211  ((computer science, artificial intelligence, a...
# 3212     ((computer science, artificial intelligence),)
# 3213     ((computer science, artificial intelligence),)
# 3214                 ((computer science, data mining),)
# 3215                             ((computer science,),)
# 3216  ((computer science, artificial intelligence, a...
# 3217  ((computer science, theoretical computer scien...
# 3219                             ((computer science,),)
# 3222  ((computer science, artificial intelligence, a...
# 3223  ((computer science, artificial intelligence, d...
# 3228  ((computer science, artificial intelligence, e...
# 3229  ((computer science, theoretical computer scien...
# 3230                 ((computer science, data mining),)
# 3231  ((computer science, machine learning, online m...
# 3232       ((computer science, computational science),)
# 3233  ((computer science, artificial intelligence, d...
# 3234  ((computer science, artificial intelligence, a...
# 3235                             ((computer science,),)
# 3236  ((computer science, artificial intelligence, a...
# 3237  ((computer science, artificial intelligence, a...
# 3238  ((computer science, artificial intelligence, a...
# 3240                 ((computer science, data mining),)
#
# [128 rows x 22 columns]

# %%
df.to_excel("tableComputerScience.xlsx")

# %%
print("Program end at "+str(datetime.now()))
# Out:
# Program end at 2017-07-27 20:14:11.832756

# %% [markdown]
# And voilà! We have the table of all descendants of the node 'software' with all the properties we think relevant!
